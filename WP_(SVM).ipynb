# %%
import pandas as pd
import numpy as np

# %%
weather01 = pd.read_csv('IndianWeatherRepository 1.csv')
weather01.iloc[0]
# Out:
# country                                    India
# location_name                         Ashoknagar
# region                            Madhya Pradesh
# latitude                                   24.57
# longitude                                  77.72
# timezone                            Asia/Kolkata
# last_updated_epoch                    1693286100
# last_updated                    2023-08-29 10:45
# temperature_celsius                         27.5
# temperature_fahrenheit                      81.5
# condition_text                     Partly cloudy
# wind_mph                                    12.8
# wind_kph                                    20.5
# wind_degree                                  281
# wind_direction                               WNW
# pressure_mb                               1008.0
# pressure_in                                29.77
# precip_mm                                    0.0
# precip_in                                    0.0
# humidity                                      67
# cloud                                         26
# feels_like_celsius                          29.7
# feels_like_fahrenheit                       85.5
# visibility_km                               10.0
# visibility_miles                             6.0
# uv_index                                     7.0
# gust_mph                                    14.8
# gust_kph                                    23.8
# air_quality_Carbon_Monoxide                243.7
# air_quality_Ozone                           45.8
# air_quality_Nitrogen_dioxide                 1.7
# air_quality_Sulphur_dioxide                  3.1
# air_quality_PM2.5                           12.6
# air_quality_PM10                            18.5
# air_quality_us-epa-index                       1
# air_quality_gb-defra-index                     2
# sunrise                                 05:59 AM
# sunset                                  06:41 PM
# moonrise                                05:42 PM
# moonset                                 03:38 AM
# moon_phase                        Waxing Gibbous
# moon_illumination                             93
# Name: 0, dtype: object

# %%
columns_to_drop =['country','timezone','last_updated_epoch','sunrise','sunset','moonrise','moonset','moon_phase','moon_illumination','wind_mph','wind_degree','wind_direction','pressure_mb','precip_in','feels_like_celsius','feels_like_fahrenheit','visibility_miles','uv_index','gust_mph','gust_kph','temperature_fahrenheit','cloud','visibility_km']
weather01 = weather01.drop(columns_to_drop, axis=1)
weather01.head()
# Out:
#   location_name          region  latitude  longitude      last_updated  \
# 0    Ashoknagar  Madhya Pradesh     24.57      77.72  2023-08-29 10:45
# 1        Raisen  Madhya Pradesh     23.33      77.80  2023-08-29 10:45
# 2    Chhindwara  Madhya Pradesh     22.07      78.93  2023-08-29 10:45
# 3         Betul  Madhya Pradesh     21.86      77.93  2023-08-29 10:45
# 4   Hoshangabad  Madhya Pradesh     22.75      77.72  2023-08-29 10:45
#
#    temperature_celsius condition_text  wind_kph  pressure_in  precip_mm  \
# 0                 27.5  Partly cloudy      20.5        29.77        0.0
# 1                 27.5          Sunny      15.5        29.78        0.0
# 2                 26.3  Partly cloudy      18.4        29.78        0.0
# 3                 25.6         Cloudy      16.9        29.80        0.0
# 4                 27.2         Cloudy      16.2        29.79        0.0
#
#    humidity  air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0        67                        243.7               45.8
# 1        70                        240.3               38.3
# 2        70                        220.3               57.2
# 3        76                        200.3               25.0
# 4        74                        257.0               30.8
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           1.7                          3.1
# 1                           2.1                          2.6
# 2                           0.6                          1.7
# 3                           1.2                          1.1
# 4                           2.2                          1.8
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0               12.6              18.5                         1
# 1               10.7              14.2                         1
# 2               16.8              20.7                         2
# 3                4.9               6.6                         1
# 4               11.4              14.8                         1
#
#    air_quality_gb-defra-index
# 0                           2
# 1                           1
# 2                           2
# 3                           1
# 4                           1

# %%
first_row = weather01.iloc[0]
print(first_row)
# Out:
# location_name                         Ashoknagar
# region                            Madhya Pradesh
# latitude                                   24.57
# longitude                                  77.72
# last_updated                    2023-08-29 10:45
# temperature_celsius                         27.5
# condition_text                     Partly cloudy
# wind_kph                                    20.5
# pressure_in                                29.77
# precip_mm                                    0.0
# humidity                                      67
# air_quality_Carbon_Monoxide                243.7
# air_quality_Ozone                           45.8
# air_quality_Nitrogen_dioxide                 1.7
# air_quality_Sulphur_dioxide                  3.1
# air_quality_PM2.5                           12.6
# air_quality_PM10                            18.5
# air_quality_us-epa-index                       1
# air_quality_gb-defra-index                     2
# Name: 0, dtype: object

# %%
#renaming our columns
weather01 = weather01.rename(columns={'location_name':'location','last_updated':'date','condition_text':'cloud_cover'})
weather01.head()
# Out:
#       location          region  latitude  longitude              date  \
# 0   Ashoknagar  Madhya Pradesh     24.57      77.72  2023-08-29 10:45
# 1       Raisen  Madhya Pradesh     23.33      77.80  2023-08-29 10:45
# 2   Chhindwara  Madhya Pradesh     22.07      78.93  2023-08-29 10:45
# 3        Betul  Madhya Pradesh     21.86      77.93  2023-08-29 10:45
# 4  Hoshangabad  Madhya Pradesh     22.75      77.72  2023-08-29 10:45
#
#    temperature_celsius    cloud_cover  wind_kph  pressure_in  precip_mm  \
# 0                 27.5  Partly cloudy      20.5        29.77        0.0
# 1                 27.5          Sunny      15.5        29.78        0.0
# 2                 26.3  Partly cloudy      18.4        29.78        0.0
# 3                 25.6         Cloudy      16.9        29.80        0.0
# 4                 27.2         Cloudy      16.2        29.79        0.0
#
#    humidity  air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0        67                        243.7               45.8
# 1        70                        240.3               38.3
# 2        70                        220.3               57.2
# 3        76                        200.3               25.0
# 4        74                        257.0               30.8
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           1.7                          3.1
# 1                           2.1                          2.6
# 2                           0.6                          1.7
# 3                           1.2                          1.1
# 4                           2.2                          1.8
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0               12.6              18.5                         1
# 1               10.7              14.2                         1
# 2               16.8              20.7                         2
# 3                4.9               6.6                         1
# 4               11.4              14.8                         1
#
#    air_quality_gb-defra-index
# 0                           2
# 1                           1
# 2                           2
# 3                           1
# 4                           1

# %%
# Converting 'date' column to datetime format
weather01['date_time'] = pd.to_datetime(weather01['date'], format='%Y-%m-%d %H:%M')
weather01.head()
# Out:
#       location          region  latitude  longitude              date  \
# 0   Ashoknagar  Madhya Pradesh     24.57      77.72  2023-08-29 10:45
# 1       Raisen  Madhya Pradesh     23.33      77.80  2023-08-29 10:45
# 2   Chhindwara  Madhya Pradesh     22.07      78.93  2023-08-29 10:45
# 3        Betul  Madhya Pradesh     21.86      77.93  2023-08-29 10:45
# 4  Hoshangabad  Madhya Pradesh     22.75      77.72  2023-08-29 10:45
#
#    temperature_celsius    cloud_cover  wind_kph  pressure_in  precip_mm  \
# 0                 27.5  Partly cloudy      20.5        29.77        0.0
# 1                 27.5          Sunny      15.5        29.78        0.0
# 2                 26.3  Partly cloudy      18.4        29.78        0.0
# 3                 25.6         Cloudy      16.9        29.80        0.0
# 4                 27.2         Cloudy      16.2        29.79        0.0
#
#    humidity  air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0        67                        243.7               45.8
# 1        70                        240.3               38.3
# 2        70                        220.3               57.2
# 3        76                        200.3               25.0
# 4        74                        257.0               30.8
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           1.7                          3.1
# 1                           2.1                          2.6
# 2                           0.6                          1.7
# 3                           1.2                          1.1
# 4                           2.2                          1.8
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0               12.6              18.5                         1
# 1               10.7              14.2                         1
# 2               16.8              20.7                         2
# 3                4.9               6.6                         1
# 4               11.4              14.8                         1
#
#    air_quality_gb-defra-index           date_time
# 0                           2 2023-08-29 10:45:00
# 1                           1 2023-08-29 10:45:00
# 2                           2 2023-08-29 10:45:00
# 3                           1 2023-08-29 10:45:00
# 4                           1 2023-08-29 10:45:00

# %%
#Now we will calculate Temporal aggregation which we will use further 
# Calculate daily average temperature, humidity, and total precipitation
daily_aggregated_data = weather01.resample('D', on='date_time').agg({
    'temperature_celsius': 'mean',
    'humidity': 'mean',
    'precip_mm': 'sum'
})

print("Daily Aggregated Data:")
print(daily_aggregated_data.head())
# Out:
# Daily Aggregated Data:
#             temperature_celsius   humidity  precip_mm
# date_time
# 2023-08-29            29.666667  59.926335       27.1
# 2023-08-30            28.246909  65.676364       26.2
# 2023-08-31            24.940182  76.690909      122.4
# 2023-09-01            25.379779  76.154412      206.0
# 2023-09-02            25.628780  75.327869      268.4

# %%
#Grouping differet locations for further actions
grouped_data = weather01.groupby(['location'])
#you can repeat this function with different locations
Ashoknagar = grouped_data.get_group('Ashoknagar')

# %%
# Now we will perform 'Moving Averages' for short term fluctuation in the dataset
# Calculate 7-day moving average of temperature
Ashoknagar['temperature_7day_ma'] = Ashoknagar['temperature_celsius'].rolling(window=7).mean()
Ashoknagar['humidity_7day_ma'] = Ashoknagar['humidity'].rolling(window=7).mean()
Ashoknagar['wind_speed_7day_ma'] = Ashoknagar['wind_kph'].rolling(window=7).mean()
print("weather01 Data with Moving Averages:")
print(Ashoknagar[['date', 'temperature_celsius', 'temperature_7day_ma','humidity','humidity_7day_ma','wind_kph','wind_speed_7day_ma']])
#Remember these are new columns in our dataset
# Out:
# weather01 Data with Moving Averages:
#                     date  temperature_celsius  temperature_7day_ma  humidity  \
# 0       2023-08-29 10:45                 27.5                  NaN        67
# 543     2023-08-30 08:45                 25.6                  NaN        71
# 1093    2023-08-31 05:15                 23.6                  NaN        81
# 1643    2023-09-01 05:15                 24.2                  NaN        77
# 2187    2023-09-02 05:15                 24.9                  NaN        73
# ...                  ...                  ...                  ...       ...
# 106248  2024-03-14 22:00                 24.0            23.871429        22
# 107339  2024-03-16 22:00                 23.4            24.200000        18
# 107889  2024-03-17 22:15                 26.2            24.871429        16
# 108440  2024-03-18 22:00                 25.1            25.057143        19
# 108989  2024-03-19 21:45                 24.7            24.942857        16
#
#         humidity_7day_ma  wind_kph  wind_speed_7day_ma
# 0                    NaN      20.5                 NaN
# 543                  NaN      18.0                 NaN
# 1093                 NaN      15.1                 NaN
# 1643                 NaN      13.3                 NaN
# 2187                 NaN      12.6                 NaN
# ...                  ...       ...                 ...
# 106248         24.000000      15.1           12.900000
# 107339         23.285714      14.0           12.900000
# 107889         21.571429      14.0           12.842857
# 108440         20.428571      15.1           13.142857
# 108989         18.714286      11.2           12.942857
#
# [199 rows x 7 columns]
# C:\Users\shree\AppData\Local\Temp\ipykernel_15732\1766989849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ashoknagar['temperature_7day_ma'] = Ashoknagar['temperature_celsius'].rolling(window=7).mean()
# C:\Users\shree\AppData\Local\Temp\ipykernel_15732\1766989849.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ashoknagar['humidity_7day_ma'] = Ashoknagar['humidity'].rolling(window=7).mean()
# C:\Users\shree\AppData\Local\Temp\ipykernel_15732\1766989849.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ashoknagar['wind_speed_7day_ma'] = Ashoknagar['wind_kph'].rolling(window=7).mean()

# %%
#  SVM model training 

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

Ashoknagar.dropna(inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_15732\1533859347.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ashoknagar.dropna(inplace=True)

# %%
# selecting the independent feature i.e., features in which the ML model will be trained 
independent_feature= ['wind_kph','pressure_in','precip_mm','humidity','air_quality_Carbon_Monoxide','air_quality_Ozone','air_quality_Nitrogen_dioxide','air_quality_Sulphur_dioxide','air_quality_PM2.5','air_quality_PM10','air_quality_us-epa-index','air_quality_gb-defra-index','temperature_7day_ma','humidity_7day_ma','wind_speed_7day_ma'] 
# selecting the targeted feature i.e., features that will be predicted based on their respective value in independent feature
targeted_feature= ['temperature_celsius']

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(Ashoknagar[independent_feature])

# %%
# splitting the dataset into the training and test sets
X_train, X_test, y_train, y_test = train_test_split(scaled_features, Ashoknagar[targeted_feature], test_size= 0.2, random_state=42)

# %%
# creating the svr model with approprieate hyperparameter tuning techniques
svr=SVR(kernel='linear',C = 100, epsilon=0.1)

# %%
y_train_flat = y_train.values.ravel() 
y_train_flat
# Out:
# array([16.5, 15.1, 22.8, 22.7, 11.5, 23.7, 21.5, 12.9, 20.9, 18.8, 14.6,
#        23.6, 20.1, 20.8, 20.3, 22.2, 22.9, 21.4, 15.7, 23.8, 24.9, 18.2,
#        26.2, 25.5, 14.1, 24.6, 14.8, 18.2, 14.5, 24. , 21.2, 13.3, 15.1,
#        13.6, 22.2, 21.2, 24.5, 23.8, 15.6, 16.8, 24.3, 14. , 13.9, 23.9,
#        23.7, 14.9, 23.3, 21.6, 13.5, 14.6, 17.3, 12.8, 25.6, 21.4, 13.9,
#        14.7, 25.2, 20.6, 16.6, 16.6, 24. , 22.2, 22. , 13.2, 23.9, 23.9,
#        22.5, 19.8, 25. , 25.8, 17.1, 16. , 15.2, 14.6, 15.8, 20.2, 22.8,
#        14.2, 18. , 16.7, 25.7, 19.9, 21.3, 14.6, 20. , 20.4, 21. , 18.7,
#        22.5, 19.6, 11.9, 23.4, 14.3, 21.1, 11.3, 22.5, 17.5, 25.1, 21. ,
#        18.5, 22. , 23.3, 14.5, 17.5, 20.6, 18.3, 24.9, 17.2, 23.4, 20.7,
#        20.2, 22.3, 12.6, 25.2, 18.2, 18. , 10.8, 18.4, 18.9, 23. , 20.1,
#        14.8, 20.4, 23.4, 20.6, 21.3, 17.1, 23.8, 20.3, 17.1, 25.5, 13.6,
#        22.2, 16.6, 21.1, 25.1, 20.8, 16.6, 13.1, 15.7, 13.1, 15. , 15.6,
#        16.6, 19.2, 14.3, 24.7, 25. , 16.9, 14.2, 21. , 16.2, 18.5, 12.6])

# %%
svr.fit(X_train, y_train_flat)
# Out:
# SVR(C=100, kernel='linear')

# %%
y_pred = svr.predict(X_test)
y_pred
# Out:
# array([22.05958037, 13.46106039, 18.87209193, 15.8474419 , 15.42072687,
#        16.82202797, 23.69065359, 22.89305006, 23.61569192, 22.34427947,
#        16.40814666, 15.06407014, 21.32734965, 21.82794312, 16.13315367,
#        23.16064688, 15.96360753, 18.20188861, 13.1800517 , 19.53499094,
#        15.66295567, 14.12513451, 15.60026274, 14.79554197, 20.94070238,
#        14.72785527, 24.21743859, 16.78671111, 20.84972371, 15.09939347,
#        15.46267587, 22.07995836, 23.95410328, 17.41708056, 20.64547385,
#        24.14766457, 14.23565549, 13.93923334, 21.65308213])
